# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
coeffs = np.array([-2, 3])
X = np.vstack([np.ones((200,)), np.linspace(0, 1, 200)])
print(X.shape)
y = coeffs @ X + np.random.normal(0, 0.3, 200)
plt.plot(X[:][1], y, '*')
plt.show()
# Out:
# (2, 200)

# %%
lin_reg = LinearRegression(fit_intercept=False)
# X_reshaped = X.reshape(-1, 1)
lin_reg.fit(X.transpose(), y)
print(lin_reg.intercept_, lin_reg.coef_)
X.shape
# Out:
# 0.0 [-2.00581542  3.06151016]
# (2, 200)

# %%
y_pred = np.array(lin_reg.coef_) @ X
plt.plot(X[:][1], y, '*')
plt.plot(X[:][1], y_pred)
plt.show()
